# %% [markdown]
# ## Chargement des données
# Toutes les tables proviennent de https://www.data.gouv.fr/

# %% [markdown]
# # Chargement de la table "sujet_tele"
# Cette table est expose le temps de diffusion par chaîne de différentes thématiques

# %%
import requests
url_sujet_tele = "https://static.data.gouv.fr/resources/classement-thematique-des-sujets-de-journaux-televises-janvier-2000-decembre-2020/20241015-124725/ina-barometre-jt-tv-donnees-quotidiennes-2000-2020-nbre-sujets-durees-202410.csv"
requests.get(url_sujet_tele)
# Vérification que l'url fonctionne
# Out:
# <Response [200]>

# %%
import pandas as pd

req = requests.get(url_sujet_tele)
print(req.content[:20])
# Observe le format des données
# Out:
# b'02/01/2000;France 3;'

# %%
# Définission du nom des colonnes
colonnes = ["Date", "Chaîne","Vide", "Thématique", "Nb_sujets", "Duree_sec"]

# %%
with open('temp.csv', 'w', encoding='latin-1') as f:
    f.write(req.text)
sujet_tele = pd.read_csv('temp.csv', sep=';', encoding='latin-1', header=None, names=colonnes) 
# latin permet d'encoder les accents

# %%
sujet_tele.head()
# Out:
#          Date    Chaîne  Vide       Thématique  Nb_sujets  Duree_sec
# 0  02/01/2000  France 3   NaN     Catastrophes          2        235
# 1  02/01/2000  France 3   NaN  Culture-loisirs          1        138
# 2  02/01/2000  France 3   NaN    Environnement          3        306
# 3  02/01/2000  France 3   NaN    International          2        241
# 4  02/01/2000  France 3   NaN          Société          2        160

# %%
sujet_tele["Thématique"].unique()
# Out:
# array(['Catastrophes', 'Culture-loisirs', 'Environnement',
#        'International', 'Société', 'Sport', 'Economie', 'Education',
#        'Politique France', 'Santé', 'Histoire-hommages', 'Justice',
#        'Faits divers', 'Sciences et techniques'], dtype=object)

# %%
# Vérification que la colonne "Vide" ne contient pas de valeurs non nulles
sujet_tele['Vide'].notna().any()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/python/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
# --> 167 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
# --> 196 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7088 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7096 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'Vide'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 2
#       1 # Vérification que la colonne "Vide" ne contient pas de valeurs non nulles
# ----> 2 sujet_tele['Vide'].notna().any()
#       3 sujet_tele['Date'] = pd.to_datetime(sujet_tele['Date'])
#
# File /opt/python/lib/python3.13/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4109
#    4110         if is_single_key:
#    4111             if self.columns.nlevels > 1:
#    4112                 return self._getitem_multilevel(key)
# -> 4113             indexer = self.columns.get_loc(key)
#    4114             if is_integer(indexer):
#    4115                 indexer = [indexer]
#    4116         else:
#
# File /opt/python/lib/python3.13/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Vide'

# %%
# Supprime la colonne "Vide"
sujet_tele = sujet_tele.drop(columns=['Vide'])
sujet_tele.head()
# Out:
#          Date    Chaîne       Thématique  Nb_sujets  Duree_sec
# 0  02/01/2000  France 3     Catastrophes          2        235
# 1  02/01/2000  France 3  Culture-loisirs          1        138
# 2  02/01/2000  France 3    Environnement          3        306
# 3  02/01/2000  France 3    International          2        241
# 4  02/01/2000  France 3          Société          2        160

# %% [markdown]
# # Chargement de la table "audience"

# %%
# Vérification du fonctionnement de l'url
url_audience = "http://www.cnc.fr/c/document_library/get_file?uuid=ac00e68f-871d-4129-ba90-977c84484bdd&groupId=18"
requests.get(url_audience)
# Out:
# <Response [200]>

# %%
req = requests.get(url_audience)
with open('temp.xlsx', 'wb') as f:
    f.write(req.content)
audience = pd.read_excel('temp.xlsx', sheet_name='PartdAudience')

# %%
audience.head(10)
# La mise en page du excel s'étale sur 4 lignes que nous allons supprimer
# Out:
#                                         Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0       Retour au menu "Audience de la télévision"        NaN        NaN
# 1                                              NaN        NaN        NaN
# 2                                              NaN        NaN        NaN
# 3  Parts d'audience des chaînes de télévision* (%)        NaN        NaN
# 4                                              NaN        NaN        NaN
# 5                                              NaN        TF1   France 2
# 6                                             1989         41       23.4
# 7                                             1990       41.9       22.1
# 8                                             1991       42.1       21.3
# 9                                             1992         41         24
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
# 5   France 3     Canal+       La 5   France 5        M6        Arte
# 6       10.3        4.4         13          -        6.4          -
# 7         11        4.3       11.7          -        7.3          -
# 8       11.3        4.6       10.9          -          8          -
# 9       13.6          5         ns          -       10.2          -
#
#   Unnamed: 9  ... Unnamed: 18 Unnamed: 19       Unnamed: 20 Unnamed: 21  \
# 0        NaN  ...         NaN         NaN               NaN         NaN
# 1        NaN  ...         NaN         NaN               NaN         NaN
# 2        NaN  ...         NaN         NaN               NaN         NaN
# 3        NaN  ...         NaN         NaN               NaN         NaN
# 4        NaN  ...         NaN         NaN               NaN         NaN
# 5         C8  ...       Gulli    France Ô  TF1 séries films    L'Equipe
# 6          -  ...           -           -                 -           -
# 7          -  ...           -           -                 -           -
# 8          -  ...           -           -                 -           -
# 9          -  ...           -           -                 -           -
#
#   Unnamed: 22 Unnamed: 23     Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27
# 0         NaN         NaN             NaN         NaN         NaN         NaN
# 1         NaN         NaN             NaN         NaN         NaN         NaN
# 2         NaN         NaN             NaN         NaN         NaN         NaN
# 3         NaN         NaN             NaN         NaN         NaN         NaN
# 4         NaN         NaN             NaN         NaN         NaN         NaN
# 5        6ter   RMC Story  RMC Découverte   Chérie 25         LCI  Franceinfo
# 6           -           -               -           -           -           -
# 7           -           -               -           -           -           -
# 8           -           -               -           -           -           -
# 9           -           -               -           -           -           -
#
# [10 rows x 28 columns]

# %%
audience = pd.read_excel('temp.xlsx',
                         sheet_name='PartdAudience',
                         skiprows=5,
                         header = 1
                        )

# %%
audience = audience.rename(columns={audience.columns[0]: 'Annee'})

# %%
audience.head()
# Out:
#   Annee   TF1  France 2  France 3  Canal+  La 5 France 5   M6  Arte C8  ...  \
# 0  1989  41.0      23.4      10.3     4.4    13        -   6.4    -  -  ...
# 1  1990  41.9      22.1      11.0     4.3  11.7        -   7.3    -  -  ...
# 2  1991  42.1      21.3      11.3     4.6  10.9        -   8.0    -  -  ...
# 3  1992  41.0      24.0      13.6     5.0    ns        -  10.2    -  -  ...
# 4  1993  41.0      24.7      14.6     4.9     -        -  11.2  0.9  -  ...
#
#   Gulli France Ô TF1 séries films L'Equipe 6ter RMC Story RMC Découverte  \
# 0     -        -                -        -    -         -              -
# 1     -        -                -        -    -         -              -
# 2     -        -                -        -    -         -              -
# 3     -        -                -        -    -         -              -
# 4     -        -                -        -    -         -              -
#
#   Chérie 25 LCI Franceinfo
# 0         -   -          -
# 1         -   -          -
# 2         -   -          -
# 3         -   -          -
# 4         -   -          -
#
# [5 rows x 28 columns]

# %% [markdown]
# # Chargement de la base "parite"

# %%
url_parite = "https://static.data.gouv.fr/resources/temps-de-parole-des-hommes-et-des-femmes-a-la-television-et-a-la-radio/20190312-191033/20190308-stats.csv"

requests.get(url_parite)
# Out:
# <Response [200]>

# %%
req = requests.get(url_parite)
print(req.content[:20])
# Out:
# b'media_type,channel_c'

# %%
with open('temp.csv', 'w', encoding='utf-8') as f:
    f.write(req.text.encode('latin-1').decode('utf-8'))
parite = pd.read_csv('temp.csv', sep=',', encoding='utf-8', header=0) 
# double encodage pour corriger les problèmes d'accents

# %%
parite.head()
# Out:
#   media_type channel_code channel_name  is_public_channel        date  \
# 0      radio          CHE    Chérie FM              False  2001-01-01
# 1      radio          CHE    Chérie FM              False  2001-01-01
# 2      radio          CHE    Chérie FM              False  2001-01-01
# 3      radio          CHE    Chérie FM              False  2001-01-01
# 4      radio          CHE    Chérie FM              False  2001-01-02
#
#   week_day school_holiday_zones  civil_holyday  hour  male_duration  \
# 0   Monday                  ABC           True     5         224.34
# 1   Monday                  ABC           True    11         160.68
# 2   Monday                  ABC           True    13         124.20
# 3   Monday                  ABC           True    18         251.20
# 4  Tuesday                  ABC          False     6         550.76
#
#    female_duration  music_duration
# 0           191.86         3180.34
# 1           137.90         3297.08
# 2           168.28         3303.96
# 3           185.58         3156.34
# 4           223.60         2818.50

# %%
# Durée totale des journaux télévisés

Journaux = sujet_tele.groupby(['Date', 'Chaîne']).agg(
    Nombre_sujets = ('Nb_sujets', 'count'),
    Duree = ('Duree_sec', 'sum'),
    ).reset_index()



Journaux.head(50)
# Out:
#           Date    Chaîne  Nombre_sujets  Duree
# 0   01/01/2000      Arte              6    684
# 1   01/01/2000  France 2              8   1990
# 2   01/01/2000  France 3              5   1287
# 3   01/01/2000        M6              5    821
# 4   01/01/2000       TF1              5   2139
# 5   01/01/2001      Arte              5   1329
# 6   01/01/2001  France 2              6   1912
# 7   01/01/2001  France 3              6    959
# 8   01/01/2001        M6              6    624
# 9   01/01/2001       TF1              6   1966
# 10  01/01/2002      Arte              5   1158
# 11  01/01/2002  France 2              6   2273
# 12  01/01/2002  France 3              4   1261
# 13  01/01/2002        M6              5    743
# 14  01/01/2002       TF1              7   2059
# 15  01/01/2003      Arte              5    939
# 16  01/01/2003  France 2              7   2043
# 17  01/01/2003  France 3              8   1406
# 18  01/01/2003        M6              5    568
# 19  01/01/2003       TF1              6   2051
# 20  01/01/2004      Arte              7   1138
# 21  01/01/2004  France 2             10   2185
# 22  01/01/2004  France 3              7   1325
# 23  01/01/2004        M6              5    463
# 24  01/01/2004       TF1              8   1927
# 25  01/01/2005      Arte              4    389
# 26  01/01/2005  France 2              4   1828
# 27  01/01/2005  France 3              4   1314
# 28  01/01/2005        M6              6    708
# 29  01/01/2005       TF1              5   2166
# 30  01/01/2006      Arte              4    675
# 31  01/01/2006  France 2              5   1616
# 32  01/01/2006  France 3              7   1761
# 33  01/01/2006        M6              7    583
# 34  01/01/2006       TF1              9   1810
# 35  01/01/2007      Arte              4    739
# 36  01/01/2007  France 2              7   1759
# 37  01/01/2007  France 3              7   1244
# 38  01/01/2007        M6              3    630
# 39  01/01/2007       TF1              8   1878
# 40  01/01/2008      Arte              4    631
# 41  01/01/2008  France 2              7   1560
# 42  01/01/2008  France 3              6   1286
# 43  01/01/2008        M6              5    613
# 44  01/01/2008       TF1              7   1821
# 45  01/01/2009      Arte              3    762
# 46  01/01/2009  France 2              8   1744
# 47  01/01/2009  France 3              6   1356
# 48  01/01/2009        M6              6    693
# 49  01/01/2009       TF1              7   1820
